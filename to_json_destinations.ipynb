# %%
import csv
import json
import pandas as pd

# %%
#read the csv file into a dataframe
destinations_df = pd.read_csv("static/data/destinations.csv")
destinations_df
# Out:
#         category  rank                          name  \
# 0   destinations     1                          Cuba
# 1   destinations     2               Hoi An, Vietnam
# 2   destinations     3             Mauritius, Africa
# 3   destinations     4           Siem Reap, Cambodia
# 4   destinations     5          Chiang Mai, Thailand
# 5   destinations     6  Grand Cayman, Cayman Islands
# 6   destinations     7                  Fes, Morocco
# 7   destinations     8              Baku, Azerbaijan
# 8   destinations     9              Kathmandu, Nepal
# 9   destinations    10                Krakow, Poland
# 10  destinations    11     Ho Chi Minh City, Vietnam
# 11  destinations    12     Lanzarote, Canary Islands
# 12  destinations    13               Santiago, Chile
# 13  destinations    14                Juneau, Alaska
# 14  destinations    15           Panama City, Panama
# 15  destinations    16         Panay Island, Visayas
# 16  destinations    17    Lombok, West Nusa Tenggara
# ...

# %%
destinations_df = destinations_df.drop(['ratingurl'], axis=1)
destinations_df
# Out:
#         category  rank                          name  \
# 0   destinations     1                          Cuba
# 1   destinations     2               Hoi An, Vietnam
# 2   destinations     3             Mauritius, Africa
# 3   destinations     4           Siem Reap, Cambodia
# 4   destinations     5          Chiang Mai, Thailand
# 5   destinations     6  Grand Cayman, Cayman Islands
# 6   destinations     7                  Fes, Morocco
# 7   destinations     8              Baku, Azerbaijan
# 8   destinations     9              Kathmandu, Nepal
# 9   destinations    10                Krakow, Poland
# 10  destinations    11     Ho Chi Minh City, Vietnam
# 11  destinations    12     Lanzarote, Canary Islands
# 12  destinations    13               Santiago, Chile
# 13  destinations    14                Juneau, Alaska
# 14  destinations    15           Panama City, Panama
# 15  destinations    16         Panay Island, Visayas
# 16  destinations    17    Lombok, West Nusa Tenggara
# ...

# %%
destinations_df['id'] = destinations_df['category'] + destinations_df['rank'].astype(str)
destinations_df
# Out:
#         category  rank                          name  \
# 0   destinations     1                          Cuba
# 1   destinations     2               Hoi An, Vietnam
# 2   destinations     3             Mauritius, Africa
# 3   destinations     4           Siem Reap, Cambodia
# 4   destinations     5          Chiang Mai, Thailand
# 5   destinations     6  Grand Cayman, Cayman Islands
# 6   destinations     7                  Fes, Morocco
# 7   destinations     8              Baku, Azerbaijan
# 8   destinations     9              Kathmandu, Nepal
# 9   destinations    10                Krakow, Poland
# 10  destinations    11     Ho Chi Minh City, Vietnam
# 11  destinations    12     Lanzarote, Canary Islands
# 12  destinations    13               Santiago, Chile
# 13  destinations    14                Juneau, Alaska
# 14  destinations    15           Panama City, Panama
# 15  destinations    16         Panay Island, Visayas
# 16  destinations    17    Lombok, West Nusa Tenggara
# ...

# %%
destinations_df = destinations_df[['id','category','rank','name','location','imageurl','description','latitude','longitude']]
destinations_df
# Out:
#                 id      category  rank                          name  \
# 0    destinations1  destinations     1                          Cuba
# 1    destinations2  destinations     2               Hoi An, Vietnam
# 2    destinations3  destinations     3             Mauritius, Africa
# 3    destinations4  destinations     4           Siem Reap, Cambodia
# 4    destinations5  destinations     5          Chiang Mai, Thailand
# 5    destinations6  destinations     6  Grand Cayman, Cayman Islands
# 6    destinations7  destinations     7                  Fes, Morocco
# 7    destinations8  destinations     8              Baku, Azerbaijan
# 8    destinations9  destinations     9              Kathmandu, Nepal
# 9   destinations10  destinations    10                Krakow, Poland
# 10  destinations11  destinations    11     Ho Chi Minh City, Vietnam
# 11  destinations12  destinations    12     Lanzarote, Canary Islands
# 12  destinations13  destinations    13               Santiago, Chile
# ...

# %%
destinations_df.dtypes
# Out:
# id              object
# category        object
# rank             int64
# name            object
# location        object
# imageurl        object
# description     object
# latitude       float64
# longitude      float64
# dtype: object

# %%
destinations_df.to_csv('restaurants_id.csv')

# %%
restaurantreviews_df.to_csv('restaurantreviews_df_id.csv')

# %%
restaurant_merged_df = restaurants_df.merge(restaurantreviews_df, on=['id','category','rank'])
restaurant_merged_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 restaurant_merged_df = restaurants_df.merge(restaurantreviews_df, on=['id','category','rank'])
#       2 restaurant_merged_df
#
# NameError: name 'restaurants_df' is not defined

# %%
restaurant_merged_df.to_csv('restaurant_merged.csv')

# %%
destinations_df.to_json('destinations.json', orient = 'records')

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            #primary key
            key = rows['']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'restaurant_merged.csv'
jsonFilePath = r'json/restaurant_merged.json'

# %%
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
