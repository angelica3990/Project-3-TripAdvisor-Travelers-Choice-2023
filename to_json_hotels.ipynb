# %%
import csv
import json
import pandas as pd

# %%
#read the csv file into a dataframe
hotels_df = pd.read_csv("static/data/hotels.csv")
hotels_df
# Out:
#    category  rank                                               name  \
# 0    hotels     1                         Tulemar Bungalows & Villas
# 1    hotels     2                            Hotel Colline de France
# 2    hotels     3                                          Ikos Aria
# 3    hotels     4                             Romance Istanbul Hotel
# 4    hotels     5                                          THE OMNIA
# 5    hotels     6                Kayakapi Premium Caves - Cappadocia
# 6    hotels     7                                   Six Senses Laamu
# 7    hotels     8                 Hamanasi Adventure and Dive Resort
# 8    hotels     9                                  Padma Resort Ubud
# 9    hotels    10                                 BLESS Hotel Madrid
# 10   hotels    11                                        Ikos Dassia
# 11   hotels    12                             Pimalai Resort and Spa
# 12   hotels    13                                  Lotte Hotel Hanoi
# ...

# %%
hotels_df['id'] = hotels_df['category'] + hotels_df['rank'].astype(str)
hotels_df = hotels_df.drop(['ratingurl'], axis=1)

# %%
hotels_df = hotels_df[['id','category','rank','name','location','imageurl','description','latitude','longitude']]
hotels_df
# Out:
#           id category  rank  \
# 0    hotels1   hotels     1
# 1    hotels2   hotels     2
# 2    hotels3   hotels     3
# 3    hotels4   hotels     4
# 4    hotels5   hotels     5
# 5    hotels6   hotels     6
# 6    hotels7   hotels     7
# 7    hotels8   hotels     8
# 8    hotels9   hotels     9
# 9   hotels10   hotels    10
# 10  hotels11   hotels    11
# 11  hotels12   hotels    12
# 12  hotels13   hotels    13
# 13  hotels14   hotels    14
# 14  hotels15   hotels    15
# 15  hotels16   hotels    16
# 16  hotels17   hotels    17
# 17  hotels18   hotels    18
# 18  hotels19   hotels    19
# 19  hotels20   hotels    20
# 20  hotels21   hotels    21
# 21  hotels22   hotels    22
# 22  hotels23   hotels    23
# 23  hotels24   hotels    24
# 24  hotels25   hotels    25
#
#                                                  name  \
# 0                          Tulemar Bungalows & Villas
# 1                             Hotel Colline de France
# ...

# %%
hotels_df.dtypes

# %%
hotels_df.to_csv('beaches_id.csv')

# %%
#read the csv file into a dataframe
hotelreviews_df = pd.read_csv("static/data/hotelreviews.csv")

# %%
hotelreviews_df

# %%
hotelreviews_df = hotelreviews_df.rename(columns={'very good':'very_good'})
hotelreviews_df

# %%
hotelreviews_df['id'] = hotelreviews_df['category'] + hotelreviews_df['rank'].astype(str)

hotelreviews_df = hotelreviews_df[['id','category','rank','name','rate','total_reviews','excellent','very_good','average','poor','terrible']]
hotelreviews_df

# %%
hotelreviews_df.dtypes

# %%
beachreviews_df.to_csv('beachreviews_id.csv')

# %%
hotels_merged_df = hotels_df.merge(hotelreviews_df, on=['id','category','rank'])
hotels_merged_df

# %%
hotels_merged_df.to_csv('hotels_merged.csv', index=False)

# %%
hotels_merged_df.to_json('hotels_merged.json', orient = 'records')

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            # Assuming a column named 'No' to
            # be the primary key
            key = rows['Ranking']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'DestinationsTripAdvisor2023.csv'
jsonFilePath = r'destination.json'

# %%
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
