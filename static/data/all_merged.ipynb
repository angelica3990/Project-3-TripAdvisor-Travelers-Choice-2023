# %%
import pandas as pd
import csv

# %%
beaches_merged_df = pd.read_csv("beaches_merged.csv")
beaches_merged_df
# Out:
#            id category  rank                                name  \
# 0    beaches1  beaches     1                     Grace Bay Beach
# 1    beaches2  beaches     2                      Varadero Beach
# 2    beaches3  beaches     3                       Turquoise Bay
# 3    beaches4  beaches     4                        Quarta Praia
# 4    beaches5  beaches     5                         Eagle Beach
# 5    beaches6  beaches     6                    Radhanagar Beach
# 6    beaches7  beaches     7                      Baia do Sancho
# 7    beaches8  beaches     8                     Trunk Bay Beach
# 8    beaches9  beaches     9                  Baia dos Golfinhos
# 9   beaches10  beaches    10                Spiaggia dei Conigli
# 10  beaches11  beaches    11                         Cable Beach
# 11  beaches12  beaches    12                    Praia da Falesia
# 12  beaches13  beaches    13  Hapuna Beach State Recreation Area
# ...

# %%
restaurants_merged_df = pd.read_csv("restaurants_merged.csv")
restaurants_merged_df
# Out:
#                id     category  rank  \
# 0    restaurants1  restaurants     1
# 1    restaurants2  restaurants     2
# 2    restaurants3  restaurants     3
# 3    restaurants4  restaurants     4
# 4    restaurants5  restaurants     5
# 5    restaurants6  restaurants     6
# 6    restaurants7  restaurants     7
# 7    restaurants8  restaurants     8
# 8    restaurants9  restaurants     9
# 9   restaurants10  restaurants    10
# 10  restaurants11  restaurants    11
# 11  restaurants12  restaurants    12
# 12  restaurants13  restaurants    13
# 13  restaurants14  restaurants    14
# 14  restaurants15  restaurants    15
# 15  restaurants16  restaurants    16
# 16  restaurants17  restaurants    17
# 17  restaurants18  restaurants    18
# 18  restaurants19  restaurants    19
# 19  restaurants20  restaurants    20
# 20  restaurants21  restaurants    21
# 21  restaurants22  restaurants    22
# 22  restaurants23  restaurants    23
# 23  restaurants24  restaurants    24
# ...

# %%
hotels_merged_df = pd.read_csv("hotels_merged.csv")
hotels_merged_df
# Out:
#           id category  rank  \
# 0    hotels1   hotels     1
# 1    hotels2   hotels     2
# 2    hotels3   hotels     3
# 3    hotels4   hotels     4
# 4    hotels5   hotels     5
# 5    hotels6   hotels     6
# 6    hotels7   hotels     7
# 7    hotels8   hotels     8
# 8    hotels9   hotels     9
# 9   hotels10   hotels    10
# 10  hotels11   hotels    11
# 11  hotels12   hotels    12
# 12  hotels13   hotels    13
# 13  hotels14   hotels    14
# 14  hotels15   hotels    15
# 15  hotels16   hotels    16
# 16  hotels17   hotels    17
# 17  hotels18   hotels    18
# 18  hotels19   hotels    19
# 19  hotels20   hotels    20
# 20  hotels21   hotels    21
# 21  hotels22   hotels    22
# 22  hotels23   hotels    23
# 23  hotels24   hotels    24
# 24  hotels25   hotels    25
#
#                                                  name  \
# 0                          Tulemar Bungalows & Villas
# 1                             Hotel Colline de France
# ...

# %%
things_merged_df = pd.read_csv("things_merged.csv")
things_merged_df
# Out:
#           id category  rank  \
# 0    things1   things     1
# 1    things2   things     2
# 2    things3   things     3
# 3    things4   things     4
# 4    things5   things     5
# 5    things6   things     6
# 6    things7   things     7
# 7    things8   things     8
# 8    things9   things     9
# 9   things10   things    10
# 10  things11   things    11
# 11  things12   things    12
# 12  things13   things    13
# 13  things14   things    14
# 14  things15   things    15
# 15  things16   things    16
# 16  things17   things    17
# 17  things18   things    18
# 18  things19   things    19
# 19  things20   things    20
# 20  things21   things    21
# 21  things22   things    22
# 22  things23   things    23
# 23  things24   things    24
# 24  things25   things    25
#
#                                                  name  \
# 0   Flagship Amsterdam Open Boat Canal Cruise - Lo...
# 1   Dubai: Red Dunes ATV, Sandsurf, Camels, Starga...
# ...

# %%
frames = [beaches_merged_df, restaurants_merged_df, hotels_merged_df,things_merged_df]
all_merged_df = pd.concat(frames)
all_merged_df
# Out:
#           id category  rank  \
# 0   beaches1  beaches     1
# 1   beaches2  beaches     2
# 2   beaches3  beaches     3
# 3   beaches4  beaches     4
# 4   beaches5  beaches     5
# ..       ...      ...   ...
# 20  things21   things    21
# 21  things22   things    22
# 22  things23   things    23
# 23  things24   things    24
# 24  things25   things    25
#
#                                                  name  \
# 0                                     Grace Bay Beach
# 1                                      Varadero Beach
# 2                                       Turquoise Bay
# 3                                        Quarta Praia
# 4                                         Eagle Beach
# ..                                                ...
# 20  Dubai: Old and Modern City Tour with Blue Mosq...
# 21         Vespa Sidecar Tour in Rome with Cappuccino
# 22  ABC Snorkel Charters Port Douglas Snorkelling ...
# 23              Paragliding Oludeniz, Fethiye, Turkey
# ...

# %%
all_merged_df.to_csv('all_merged.csv', index = False)

# %%
import sqlalchemy
# Import method to connect to database
from sqlalchemy import create_engine

# Import connection string from config.py to connect to postgresql
# from config import conn_string
engine = create_engine("postgresql://postgres:jasmine69@localhost:5432/project3")
# test is the database name we connect to; if you create table in a different db, change test to that

# %%
# Autoload table from database to build metadata
table_name = 'data'
metadata = sqlalchemy.schema.MetaData(bind=engine)
table_inspect = sqlalchemy.Table(table_name, metadata, autoload=True, autoload_with=engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
# Session is a temporary binding to our DB
from sqlalchemy.orm import Session
from sqlalchemy.orm import sessionmaker
import time


Session = sessionmaker(bind=engine)


# Bulk Insert the dataframe into the database table (commit changes)


with Session() as session:        
    all_merged_df.to_sql(table_name, con=engine, if_exists='replace', index=False)
    session.commit()

    
# Query count of rows in table to confirm data was populated
count = 0
count = session.query(table_inspect).count()
print('Count of rows in foodinspect table after df to sql insert: ', count)
# Out:
# Count of rows in foodinspect table after df to sql insert:  100

# %%
# Explicit Close for safety

session.close()
