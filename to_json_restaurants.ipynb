# %%
import csv
import json
import pandas as pd

# %%
#read the csv file into a dataframe
restaurants_df = pd.read_csv("static/data/restaurants.csv")
restaurants_df
# Out:
#        category  rank                                               name  \
# 0   restaurants     1                     The Old Stamp House Restaurant
# 1   restaurants     2                                    Oro Restaurante
# 2   restaurants     3                            Madonnina del Pescatore
# 3   restaurants     4                                 Martin Berasategui
# 4   restaurants     5                                            El Xato
# 5   restaurants     6                            Ristorante Villa Crespi
# 6   restaurants     7          Guillaume Scheer - Les Plaisirs Gourmands
# 7   restaurants     8                                   Sachi Heliopolis
# 8   restaurants     9                             Auberge Du Vieux Puits
# 9   restaurants    10                               Paul Ainsworth at No
# 10  restaurants    11                                         La Colombe
# 11  restaurants    12                                 Restaurante Origem
# 12  restaurants    13                                          The Grove
# 13  restaurants    14                                   Sails Restaurant
# 14  restaurants    15                                                PIC
# 15  restaurants    16                        Ristorante Don Alfonso 1890
# 16  restaurants    17                                         Akira Back
# 17  restaurants    18                                              Maido
# 18  restaurants    19                                      Lahaina Grill
# 19  restaurants    20                         5 Gourmet Restaurant & Bar
# 20  restaurants    21                                              Chila
# 21  restaurants    22                                    Summer Pavilion
# 22  restaurants    23                                      Tin Lung Heen
# 23  restaurants    24  Mandarin Grill + Bar at Mandarin Oriental, Hon...
# 24  restaurants    25                                   Restaurante 1621
#
#                            location  \
# 0         Ambleside, United Kingdom
# 1            Rio de Janeiro, Brazil
# 2                 Senigallia, Italy
# 3               Lasarte-Oria, Spain
# 4                   La Nucia, Spain
# 5            Orta San Giulio, Italy
# 6              Schiltigheim, France
# 7                      Cairo, Egypt
# 8              Fontjoncouse, France
# 9           Padstow, United Kingdom
# 10         Constantia, South Africa
# 11                 Salvador, Brazil
# 12    Auckland Central, New Zealand
# 13    Auckland Central, New Zealand
# 14                  Valence, France
# 15  Sant'Agata sui Due Golfi, Italy
# 16                Bangkok, Thailand
# 17                       Lima, Peru
# 18                  Lahaina, Hawaii
# 19               Stuttgart, Germany
# 20          Buenos Aires, Argentina
# 21             Singapore, Singapore
# 22                 Hong Kong, China
# 23                 Hong Kong, China
# 24              Cartagena, Colombia
#
#                                              imageurl  \
# 0   https://media-cdn.tripadvisor.com/media/photo-...
# 1   https://media-cdn.tripadvisor.com/media/photo-...
# 2   https://media-cdn.tripadvisor.com/media/photo-...
# 3   https://media-cdn.tripadvisor.com/media/photo-...
# 4   https://media-cdn.tripadvisor.com/media/photo-...
# 5   https://media-cdn.tripadvisor.com/media/photo-...
# 6   https://media-cdn.tripadvisor.com/media/photo-...
# 7   https://media-cdn.tripadvisor.com/media/photo-...
# 8   https://media-cdn.tripadvisor.com/media/photo-...
# 9   https://media-cdn.tripadvisor.com/media/photo-...
# 10  https://media-cdn.tripadvisor.com/media/photo-...
# 11  https://media-cdn.tripadvisor.com/media/photo-...
# 8   /Restaurant_Review-g674102-d794269-Reviews-Aub...
# 9   /Restaurant_Review-g315948-d731121-Reviews-Pau...
# 10  /Restaurant_Review-g312660-d1009903-Reviews-La...
# 11  /Restaurant_Review-g303272-d10715594-Reviews-R...
# 12  /Restaurant_Review-g255106-d726050-Reviews-The...
# 13  /Restaurant_Review-g255106-d725114-Reviews-Sai...
# 14  /Restaurant_Review-g187272-d719830-Reviews-PIC...
# 15  /Restaurant_Review-g644245-d716377-Reviews-Ris...
# 16  /Restaurant_Review-g293916-d13275747-Reviews-A...
# 17  /Restaurant_Review-g294316-d1759465-Reviews-Ma...
# 18  /Restaurant_Review-g60634-d404360-Reviews-Laha...
# 19  /Restaurant_Review-g187291-d2142723-Reviews-5-...
# 20  /Restaurant_Review-g312741-d1748914-Reviews-Ch...
# 21  /Restaurant_Review-g294265-d796940-Reviews-Sum...
# 22  /Restaurant_Review-g294217-d2399904-Reviews-Ti...
# 23  /Restaurant_Review-g294217-d941989-Reviews-Man...
# 24  /Restaurant_Review-g297476-d2140318-Reviews-Re...

# %%
restaurants_df = restaurants_df.drop(['ratingurl'], axis=1)
restaurants_df

# %%
restaurants_df['id'] = restaurants_df['category'] + restaurants_df['rank'].astype(str)
restaurants_df

# %%
restaurants_df = restaurants_df[['id','category','rank','name','location','imageurl','description','latitude','longitude']]
restaurants_df

# %%
restaurants_df.dtypes

# %%
restaurants_df.to_csv('restaurants_id.csv')

# %%
#read the csv file into a dataframe
restaurantreviews_df = pd.read_csv("static/data/restaurantreviews.csv")

# %%
restaurantreviews_df['id'] = restaurantreviews_df['category'] + restaurantreviews_df['rank'].astype(str)
restaurantreviews_df = restaurantreviews_df[['id','category','rank','rate','total_reviews','excellent','very_good','average','poor','terrible']]
restaurantreviews_df

# %%
restaurantreviews_df.dtypes

# %%
restaurantreviews_df.to_csv('restaurantreviews_df_id.csv')

# %%
restaurant_merged_df = restaurants_df.merge(restaurantreviews_df, on=['id','category','rank'])
restaurant_merged_df

# %%
restaurant_merged_df.to_csv('restaurant_merged.csv')

# %%
restaurant_merged_df.to_json('restaurants_merged.json', orient = 'records')

# %%
# Function to convert a CSV to JSON
# Takes the file paths as arguments
def make_json(csvFilePath, jsonFilePath):
     
    # create a dictionary
    data = {}
     
    # Open a csv reader called DictReader
    with open(csvFilePath, encoding='utf-8') as csvf:
        csvReader = csv.DictReader(csvf)
         
        # Convert each row into a dictionary
        # and add it to data
        for rows in csvReader:
             
            #primary key
            key = rows['']
            data[key] = rows
 
    # Open a json writer, and use the json.dumps()
    # function to dump data
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf:
        jsonf.write(json.dumps(data, indent=4))

# %%
# Driver Code
 
# Decide the two file paths according to your
# computer system
csvFilePath = r'restaurant_merged.csv'
jsonFilePath = r'json/restaurant_merged.json'

# %%
# Call the make_json function
make_json(csvFilePath, jsonFilePath)
